# %% [markdown]
# <a href="https://colab.research.google.com/github/GyokuroKunso/Aula_de_JogosDigitais/blob/main/EstudosDeBibliotecaPandas(pd).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dfGames = pd.DataFrame(
    {
        "Jogo":["Castelvania","Dark Souls","Final Fantasy","Super Mario Bros","Fate stay/night","Dance Dance Evolution","Devil May Cry"],
        "Ano":[1986,2011,1987,1985,2004,2010,2001],
        "Estilo" :["Metroidvania", "Soulslike", "RPG de Turno","RPG de Ação","Visual Novel","Ritmo Musical","Hack and Slash"]
    }
)

# %%
dfGames
# Out:
#                     Jogo   Ano          Estilo
# 0            Castelvania  1986    Metroidvania
# 1             Dark Souls  2011       Soulslike
# 2          Final Fantasy  1987    RPG de Turno
# 3       Super Mario Bros  1985     RPG de Ação
# 4        Fate stay/night  2004    Visual Novel
# 5  Dance Dance Evolution  2010   Ritmo Musical
# 6          Devil May Cry  2001  Hack and Slash

# %%
dfGames['Ano']
# Out:
# 0    1986
# 1    2011
# 2    1987
# 3    1985
# 4    2004
# 5    2010
# 6    2001
# Name: Ano, dtype: int64

# %%
dfGames['Jogo']
# Out:
# 0              Castelvania
# 1               Dark Souls
# 2            Final Fantasy
# 3         Super Mario Bros
# 4          Fate stay/night
# 5    Dance Dance Evolution
# 6            Devil May Cry
# Name: Jogo, dtype: object

# %%
dfGames['Estilo']
# Out:
# 0      Metroidvania
# 1         Soulslike
# 2      RPG de Turno
# 3       RPG de Ação
# 4      Visual Novel
# 5     Ritmo Musical
# 6    Hack and Slash
# Name: Estilo, dtype: object

# %%
dfGames['Ano'].min()
# Out:
# 1985

# %%
dfGames['Ano'].max()
# Out:
# 2011

# %%
dfGames.describe()
# Out:
#                Ano
# count     7.000000
# mean   1997.714286
# std      11.484980
# min    1985.000000
# 25%    1986.500000
# 50%    2001.000000
# 75%    2007.000000
# max    2011.000000

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Visualizar as n primeiras linhas
titanic.head(4)

# %%
idades = titanic['Age']
idades.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
class3 = titanic[titanic['Pclass'] == 3]

# %%
class3[class3['Survived'] ==1].count()
# Out:
# PassengerId    119
# Survived       119
# Pclass         119
# Name           119
# Sex            119
# Age             85
# SibSp          119
# Parch          119
# Ticket         119
# Fare           119
# Cabin            6
# Embarked       119
# dtype: int64

# %%
idade_sexo = titanic[['Age','Sex']]
idade_sexo.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male
